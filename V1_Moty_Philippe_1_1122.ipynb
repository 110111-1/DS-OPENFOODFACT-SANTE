# %% [markdown]
# # Projet- 3 : Concevez une application au service de la santé publique

# %% [markdown]
# ![combo_logo.jpg](attachment:combo_logo.jpg)

# %% [markdown]
# ## Introduction
# ***
# - Traiter le jeu de données afin de repérer des variables pertinentes pour les traitements à venir. Automatiser ces traitements pour éviter de répéter ces opérations.
#
# - **L'idée de l'application :** aide à l'identification des produits à surveiller dans le cas de régime alimentaire liées à la surveillance en utilisant la base d'OpenFood Facts
#
# ***

# %% [markdown]
# ## Environnement

# %%
import pandas as pd
import numpy as np
import sys
import warnings
import IPython as ip
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import missingno as msno 
# Configuration pour travail avec fichier python "tools" de fonctions
# %load_ext autoreload
# %aimport tools

# Set option
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Recharger les modules pour la conception des fichiers tools

# %autoreload 1

warnings.filterwarnings("ignore")

# %%
# Afficher menu
from jyquickhelper import add_notebook_menu
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null) {
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;")
#          .replace(">", "&gt;").replace("&", "&amp;");
#         }
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += end_format + "</ul>\n";
#             format_open -= 1;
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2);
#         text_menu += begin_format + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#         format_open += 1;
#     }
#     while (1 < memo_level) {
#         text_menu += end_format + "</ul>\n";
#         memo_level -= 1;
#         format_open -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#
#     while (format_open > 0) {
#         text_menu += end_format;
#         format_open -= 1;
#     }
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<a href="#__HREF__">__TITLE__</a>';
#     var send = "";
#     var begin_format = '<li>';
#     var end_format = '</li>';
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item,
#        begin_format, end_format);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# # Chargement des données

# %%
# Import données
data = pd.read_csv('assets/datas/openfoodfacts.csv', sep='\t', low_memory=False)

# %% [markdown]
# # Description du jeu de données

# %%
# On visualise quelques lignes
data.head(3)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
# 1  0000000004530  http://world-fr.openfoodfacts.org/produit/0000...
# 2  0000000004559  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
#
#   generic_name quantity packaging packaging_tags           brands  \
# 0          NaN      1kg       NaN            NaN  Ferme t'y R'nao
# 1          NaN      NaN       NaN            NaN              NaN
# 2          NaN      NaN       NaN            NaN   Torn & Glasser
#
#        brands_tags categories categories_tags categories_fr origins  \
# 0  ferme-t-y-r-nao        NaN             NaN           NaN     NaN
# 1              NaN        NaN             NaN           NaN     NaN
# 2     torn-glasser        NaN             NaN           NaN     NaN
#
#   origins_tags manufacturing_places manufacturing_places_tags labels  \
# 0          NaN                  NaN                       NaN    NaN
# 1          NaN                  NaN                       NaN    NaN
# 2          NaN                  NaN                       NaN    NaN
#
#   labels_tags labels_fr emb_codes emb_codes_tags first_packaging_code_geo  \
# 0         NaN       NaN       NaN            NaN                      NaN
# 1         NaN       NaN       NaN            NaN                      NaN
# 2         NaN       NaN       NaN            NaN                      NaN
#
#   cities cities_tags purchase_places stores countries    countries_tags  \
# 0    NaN         NaN             NaN    NaN     en:FR         en:france
# 1    NaN         NaN             NaN    NaN        US  en:united-states
# 2    NaN         NaN             NaN    NaN        US  en:united-states
#
#   countries_fr                                   ingredients_text allergens  \
# 0       France                                                NaN       NaN
# 1   États-Unis  Bananas, vegetable oil (coconut oil, corn oil ...       NaN
# 2   États-Unis  Peanuts, wheat flour, sugar, rice flour, tapio...       NaN
#
#   allergens_fr traces traces_tags traces_fr     serving_size  no_nutriments  \
# 0          NaN    NaN         NaN       NaN              NaN            NaN
# 1          NaN    NaN         NaN       NaN     28 g (1 ONZ)            NaN
# 2          NaN    NaN         NaN       NaN  28 g (0.25 cup)            NaN
#
#    additives_n                                          additives  \
# 0          NaN                                                NaN
# 1          0.0   [ bananas -> en:bananas  ]  [ vegetable-oil -...
# 2          0.0   [ peanuts -> en:peanuts  ]  [ wheat-flour -> ...
#
#   additives_tags additives_fr  ingredients_from_palm_oil_n  \
# 0            NaN          NaN                          NaN
# 1            NaN          NaN                          0.0
# 2            NaN          NaN                          0.0
#
#    ingredients_from_palm_oil ingredients_from_palm_oil_tags  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
#
#    ingredients_that_may_be_from_palm_oil_n  \
# 0                                      NaN
# 1                                      0.0
# 2                                      0.0
#
#    ingredients_that_may_be_from_palm_oil  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
#
#   ingredients_that_may_be_from_palm_oil_tags  nutrition_grade_uk  \
# 0                                        NaN                 NaN
# 1                                        NaN                 NaN
# 2                                        NaN                 NaN
#
#   nutrition_grade_fr pnns_groups_1 pnns_groups_2  \
# 0                NaN           NaN           NaN
# 1                  d           NaN           NaN
# 2                  b           NaN           NaN
#
#                                               states  \
# 0  en:to-be-completed, en:nutrition-facts-to-be-c...
# 1  en:to-be-completed, en:nutrition-facts-complet...
# 2  en:to-be-completed, en:nutrition-facts-complet...
#
#                                          states_tags  \
# 0  en:to-be-completed,en:nutrition-facts-to-be-co...
# 1  en:to-be-completed,en:nutrition-facts-complete...
# 2  en:to-be-completed,en:nutrition-facts-complete...
#
#                                            states_fr main_category  \
# 0  A compléter,Informations nutritionnelles à com...           NaN
# 1  A compléter,Informations nutritionnelles compl...           NaN
# 2  A compléter,Informations nutritionnelles compl...           NaN
#
#   main_category_fr image_url image_small_url  energy_100g  \
# 0              NaN       NaN             NaN          NaN
# 1              NaN       NaN             NaN       2243.0
# 2              NaN       NaN             NaN       1941.0
#
#    energy-from-fat_100g  fat_100g  saturated-fat_100g  butyric-acid_100g  \
# 0                   NaN       NaN                 NaN                NaN
# 1                   NaN     28.57               28.57                NaN
# 2                   NaN     17.86                0.00                NaN
#
#    caproic-acid_100g  caprylic-acid_100g  capric-acid_100g  lauric-acid_100g  \
# 0                NaN                 NaN               NaN               NaN
# 1                NaN                 NaN               NaN               NaN
# 2                NaN                 NaN               NaN               NaN
#
#    myristic-acid_100g  palmitic-acid_100g  stearic-acid_100g  \
# 0                 NaN                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2                 NaN                 NaN                NaN
#
#    arachidic-acid_100g  behenic-acid_100g  lignoceric-acid_100g  \
# 0                  NaN                NaN                   NaN
# 1                  NaN                NaN                   NaN
# 2                  NaN                NaN                   NaN
#
#    cerotic-acid_100g  montanic-acid_100g  melissic-acid_100g  \
# 0                NaN                 NaN                 NaN
# 1                NaN                 NaN                 NaN
# 2                NaN                 NaN                 NaN
#
#    monounsaturated-fat_100g  polyunsaturated-fat_100g  omega-3-fat_100g  \
# 0                       NaN                       NaN               NaN
# 1                       NaN                       NaN               NaN
# 2                       NaN                       NaN               NaN
#
#    alpha-linolenic-acid_100g  eicosapentaenoic-acid_100g  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
#
#    docosahexaenoic-acid_100g  omega-6-fat_100g  linoleic-acid_100g  \
# 0                        NaN               NaN                 NaN
# 1                        NaN               NaN                 NaN
# 2                        NaN               NaN                 NaN
#
#    arachidonic-acid_100g  gamma-linolenic-acid_100g  \
# 0                    NaN                        NaN
# 1                    NaN                        NaN
# 2                    NaN                        NaN
#
#    dihomo-gamma-linolenic-acid_100g  omega-9-fat_100g  oleic-acid_100g  \
# 0                               NaN               NaN              NaN
# 1                               NaN               NaN              NaN
# 2                               NaN               NaN              NaN
#
#    elaidic-acid_100g  gondoic-acid_100g  mead-acid_100g  erucic-acid_100g  \
# 0                NaN                NaN             NaN               NaN
# 1                NaN                NaN             NaN               NaN
# 2                NaN                NaN             NaN               NaN
#
#    nervonic-acid_100g  trans-fat_100g  cholesterol_100g  carbohydrates_100g  \
# 0                 NaN             NaN               NaN                 NaN
# 1                 NaN             0.0             0.018               64.29
# 2                 NaN             0.0             0.000               60.71
#
#    sugars_100g  sucrose_100g  glucose_100g  fructose_100g  lactose_100g  \
# 0          NaN           NaN           NaN            NaN           NaN
# 1        14.29           NaN           NaN            NaN           NaN
# 2        17.86           NaN           NaN            NaN           NaN
#
#    maltose_100g  maltodextrins_100g  starch_100g  polyols_100g  fiber_100g  \
# 0           NaN                 NaN          NaN           NaN         NaN
# 1           NaN                 NaN          NaN           NaN         3.6
# 2           NaN                 NaN          NaN           NaN         7.1
#
#    proteins_100g  casein_100g  serum-proteins_100g  nucleotides_100g  \
# 0            NaN          NaN                  NaN               NaN
# 1           3.57          NaN                  NaN               NaN
# 2          17.86          NaN                  NaN               NaN
#
#    salt_100g  sodium_100g  alcohol_100g  vitamin-a_100g  beta-carotene_100g  \
# 0        NaN          NaN           NaN             NaN                 NaN
# 1      0.000         0.00           NaN             0.0                 NaN
# 2      0.635         0.25           NaN             0.0                 NaN
#
#    vitamin-d_100g  vitamin-e_100g  vitamin-k_100g  vitamin-c_100g  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN          0.0214
# 2             NaN             NaN             NaN          0.0000
#
#    vitamin-b1_100g  vitamin-b2_100g  vitamin-pp_100g  vitamin-b6_100g  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
#
#    vitamin-b9_100g  folates_100g  vitamin-b12_100g  biotin_100g  \
# 0              NaN           NaN               NaN          NaN
# 1              NaN           NaN               NaN          NaN
# 2              NaN           NaN               NaN          NaN
#
#    pantothenic-acid_100g  silica_100g  bicarbonate_100g  potassium_100g  \
# 0                    NaN          NaN               NaN             NaN
# 1                    NaN          NaN               NaN             NaN
# 2                    NaN          NaN               NaN             NaN
#
#    chloride_100g  calcium_100g  phosphorus_100g  iron_100g  magnesium_100g  \
# 0            NaN           NaN              NaN        NaN             NaN
# 1            NaN         0.000              NaN    0.00129             NaN
# 2            NaN         0.071              NaN    0.00129             NaN
#
#    zinc_100g  copper_100g  manganese_100g  fluoride_100g  selenium_100g  \
# 0        NaN          NaN             NaN            NaN            NaN
# 1        NaN          NaN             NaN            NaN            NaN
# 2        NaN          NaN             NaN            NaN            NaN
#
#    chromium_100g  molybdenum_100g  iodine_100g  caffeine_100g  taurine_100g  \
# 0            NaN              NaN          NaN            NaN           NaN
# 1            NaN              NaN          NaN            NaN           NaN
# 2            NaN              NaN          NaN            NaN           NaN
#
#    ph_100g  fruits-vegetables-nuts_100g  collagen-meat-protein-ratio_100g  \
# 0      NaN                          NaN                               NaN
# 1      NaN                          NaN                               NaN
# 2      NaN                          NaN                               NaN
#
#    cocoa_100g  chlorophyl_100g  carbon-footprint_100g  \
# 0         NaN              NaN                    NaN
# 1         NaN              NaN                    NaN
# 2         NaN              NaN                    NaN
#
#    nutrition-score-fr_100g  nutrition-score-uk_100g  glycemic-index_100g  \
# 0                      NaN                      NaN                  NaN
# 1                     14.0                     14.0                  NaN
# 2                      0.0                      0.0                  NaN
#
#    water-hardness_100g
# 0                  NaN
# 1                  NaN
# 2                  NaN

# %%
# Taille du jeu de données et nombre de variables dubliquées
tools.get_info_data(data)
# Out:
# ------------------------------------------------------------------
# LES DONNES
#
# Nombre de lignes : 320772 lignes
# Nombre de colonnes : 162 colonnes
# Nombre d'éléments dupliqués dans le dataframe : 0 eléments
# Nombre total de données manquantes dans le dataframe : 39608589 données manquantes sur 51965064 (76.22%)

# %%
# On liste les colonnes
data.columns.to_list()
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_fr',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_fr',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_fr',
#  'ingredients_text',
#  'allergens',
#  'allergens_fr',
#  'traces',
#  'traces_tags',
#  'traces_fr',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_fr',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
#  'ingredients_that_may_be_from_palm_oil_n',
#  'ingredients_that_may_be_from_palm_oil',
#  'ingredients_that_may_be_from_palm_oil_tags',
#  'nutrition_grade_uk',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'states',
#  'states_tags',
#  'states_fr',
#  'main_category',
#  'main_category_fr',
#  'image_url',
#  'image_small_url',
#  'energy_100g',
#  'energy-from-fat_100g',
#  'fat_100g',
#  'saturated-fat_100g',
#  'butyric-acid_100g',
#  'caproic-acid_100g',
#  'caprylic-acid_100g',
#  'capric-acid_100g',
#  'lauric-acid_100g',
#  'myristic-acid_100g',
#  'palmitic-acid_100g',
#  'stearic-acid_100g',
#  'arachidic-acid_100g',
#  'behenic-acid_100g',
#  'lignoceric-acid_100g',
#  'cerotic-acid_100g',
#  'montanic-acid_100g',
#  'melissic-acid_100g',
#  'monounsaturated-fat_100g',
#  'polyunsaturated-fat_100g',
#  'omega-3-fat_100g',
#  'alpha-linolenic-acid_100g',
#  'eicosapentaenoic-acid_100g',
#  'docosahexaenoic-acid_100g',
#  'omega-6-fat_100g',
#  'linoleic-acid_100g',
#  'arachidonic-acid_100g',
#  'gamma-linolenic-acid_100g',
#  'dihomo-gamma-linolenic-acid_100g',
#  'omega-9-fat_100g',
#  'oleic-acid_100g',
#  'elaidic-acid_100g',
#  'gondoic-acid_100g',
#  'mead-acid_100g',
#  'erucic-acid_100g',
#  'nervonic-acid_100g',
#  'trans-fat_100g',
#  'cholesterol_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'sucrose_100g',
#  'glucose_100g',
#  'fructose_100g',
#  'lactose_100g',
#  'maltose_100g',
#  'maltodextrins_100g',
#  'starch_100g',
#  'polyols_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'casein_100g',
#  'serum-proteins_100g',
#  'nucleotides_100g',
#  'salt_100g',
#  'sodium_100g',
#  'alcohol_100g',
#  'vitamin-a_100g',
#  'beta-carotene_100g',
#  'vitamin-d_100g',
#  'vitamin-e_100g',
#  'vitamin-k_100g',
#  'vitamin-c_100g',
#  'vitamin-b1_100g',
#  'vitamin-b2_100g',
#  'vitamin-pp_100g',
#  'vitamin-b6_100g',
#  'vitamin-b9_100g',
#  'folates_100g',
#  'vitamin-b12_100g',
#  'biotin_100g',
#  'pantothenic-acid_100g',
#  'silica_100g',
#  'bicarbonate_100g',
#  'potassium_100g',
#  'chloride_100g',
#  'calcium_100g',
#  'phosphorus_100g',
#  'iron_100g',
#  'magnesium_100g',
#  'zinc_100g',
#  'copper_100g',
#  'manganese_100g',
#  'fluoride_100g',
#  'selenium_100g',
#  'chromium_100g',
#  'molybdenum_100g',
#  'iodine_100g',
#  'caffeine_100g',
#  'taurine_100g',
#  'ph_100g',
#  'fruits-vegetables-nuts_100g',
#  'collagen-meat-protein-ratio_100g',
#  'cocoa_100g',
#  'chlorophyl_100g',
#  'carbon-footprint_100g',
#  'nutrition-score-fr_100g',
#  'nutrition-score-uk_100g',
#  'glycemic-index_100g',
#  'water-hardness_100g']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320772 entries, 0 to 320771
# Columns: 162 entries, code to water-hardness_100g
# dtypes: float64(106), object(56)
# memory usage: 396.5+ MB

# %%
# Informations sur le type des variables
tools.get_types_variables(data,True,True,True)
# Out:
# -------------------------------------------------------------
# Type de variable pour chacune des variables
# code                                           object
# url                                            object
# creator                                        object
# created_t                                      object
# created_datetime                               object
# last_modified_t                                object
# last_modified_datetime                         object
# product_name                                   object
# generic_name                                   object
# quantity                                       object
# packaging                                      object
# packaging_tags                                 object
# brands                                         object
# brands_tags                                    object
# categories                                     object
# categories_tags                                object
# categories_fr                                  object
# origins                                        object
# origins_tags                                   object
# manufacturing_places                           object
# manufacturing_places_tags                      object
# labels                                         object
# labels_tags                                    object
# labels_fr                                      object
# emb_codes                                      object
# emb_codes_tags                                 object
# first_packaging_code_geo                       object
# cities                                         object
# cities_tags                                    object
# purchase_places                                object
# stores                                         object
# countries                                      object
# countries_tags                                 object
# countries_fr                                   object
# ingredients_text                               object
# allergens                                      object
# allergens_fr                                   object
# traces                                         object
# traces_tags                                    object
# traces_fr                                      object
# serving_size                                   object
# no_nutriments                                 float64
# additives_n                                   float64
# additives                                      object
# additives_tags                                 object
# additives_fr                                   object
# ingredients_from_palm_oil_n                   float64
# ingredients_from_palm_oil                     float64
# ingredients_from_palm_oil_tags                 object
# ingredients_that_may_be_from_palm_oil_n       float64
# ingredients_that_may_be_from_palm_oil         float64
# ingredients_that_may_be_from_palm_oil_tags     object
# nutrition_grade_uk                            float64
# nutrition_grade_fr                             object
# pnns_groups_1                                  object
# pnns_groups_2                                  object
# states                                         object
# states_tags                                    object
# states_fr                                      object
# main_category                                  object
# main_category_fr                               object
# image_url                                      object
# image_small_url                                object
# energy_100g                                   float64
# energy-from-fat_100g                          float64
# fat_100g                                      float64
# saturated-fat_100g                            float64
# butyric-acid_100g                             float64
# caproic-acid_100g                             float64
# caprylic-acid_100g                            float64
# capric-acid_100g                              float64
# lauric-acid_100g                              float64
# myristic-acid_100g                            float64
# palmitic-acid_100g                            float64
# stearic-acid_100g                             float64
# arachidic-acid_100g                           float64
# behenic-acid_100g                             float64
# lignoceric-acid_100g                          float64
# cerotic-acid_100g                             float64
# montanic-acid_100g                            float64
# melissic-acid_100g                            float64
# monounsaturated-fat_100g                      float64
# polyunsaturated-fat_100g                      float64
# omega-3-fat_100g                              float64
# alpha-linolenic-acid_100g                     float64
# eicosapentaenoic-acid_100g                    float64
# docosahexaenoic-acid_100g                     float64
# omega-6-fat_100g                              float64
# linoleic-acid_100g                            float64
# arachidonic-acid_100g                         float64
# gamma-linolenic-acid_100g                     float64
# dihomo-gamma-linolenic-acid_100g              float64
# omega-9-fat_100g                              float64
# oleic-acid_100g                               float64
# elaidic-acid_100g                             float64
# gondoic-acid_100g                             float64
# mead-acid_100g                                float64
# erucic-acid_100g                              float64
# nervonic-acid_100g                            float64
# trans-fat_100g                                float64
# cholesterol_100g                              float64
# carbohydrates_100g                            float64
# sugars_100g                                   float64
# sucrose_100g                                  float64
# glucose_100g                                  float64
# fructose_100g                                 float64
# lactose_100g                                  float64
# maltose_100g                                  float64
# maltodextrins_100g                            float64
# starch_100g                                   float64
# polyols_100g                                  float64
# fiber_100g                                    float64
# proteins_100g                                 float64
# casein_100g                                   float64
# serum-proteins_100g                           float64
# nucleotides_100g                              float64
# salt_100g                                     float64
# sodium_100g                                   float64
# alcohol_100g                                  float64
# vitamin-a_100g                                float64
# beta-carotene_100g                            float64
# vitamin-d_100g                                float64
# vitamin-e_100g                                float64
# vitamin-k_100g                                float64
# vitamin-c_100g                                float64
# vitamin-b1_100g                               float64
# vitamin-b2_100g                               float64
# vitamin-pp_100g                               float64
# vitamin-b6_100g                               float64
# vitamin-b9_100g                               float64
# folates_100g                                  float64
# vitamin-b12_100g                              float64
# biotin_100g                                   float64
# pantothenic-acid_100g                         float64
# silica_100g                                   float64
# bicarbonate_100g                              float64
# potassium_100g                                float64
# chloride_100g                                 float64
# calcium_100g                                  float64
# phosphorus_100g                               float64
# iron_100g                                     float64
# magnesium_100g                                float64
# zinc_100g                                     float64
# copper_100g                                   float64
# manganese_100g                                float64
# fluoride_100g                                 float64
# selenium_100g                                 float64
# chromium_100g                                 float64
# molybdenum_100g                               float64
# iodine_100g                                   float64
# caffeine_100g                                 float64
# taurine_100g                                  float64
# ph_100g                                       float64
# fruits-vegetables-nuts_100g                   float64
# collagen-meat-protein-ratio_100g              float64
# cocoa_100g                                    float64
# chlorophyl_100g                               float64
# carbon-footprint_100g                         float64
# nutrition-score-fr_100g                       float64
# nutrition-score-uk_100g                       float64
# glycemic-index_100g                           float64
# water-hardness_100g                           float64
# dtype: object
# ----------------------------------------------------------
# Répartition des types de variable
# <style type="text/css">
# #T_73224_row0_col0, #T_73224_row0_col1 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_73224_row1_col0, #T_73224_row1_col1 {
#   background-color: #00004c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_73224">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73224_level0_col0" class="col_heading level0 col0" >Nombre par type de variable</th>
#       <th id="T_73224_level0_col1" class="col_heading level0 col1" >% des types de variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73224_level0_row0" class="row_heading level0 row0" >float64</th>
#       <td id="T_73224_row0_col0" class="data row0 col0" >106</td>
#       <td id="T_73224_row0_col1" class="data row0 col1" >65.430000</td>
#     </tr>
#     <tr>
#       <th id="T_73224_level0_row1" class="row_heading level0 row1" >object</th>
#       <td id="T_73224_row1_col0" class="data row1 col0" >56</td>
#       <td id="T_73224_row1_col1" class="data row1 col1" >34.570000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Description des varialbles categorielles
tools.get_description_variables(data,type_var='categ')
# Out:
#                                              count  unique  \
# code                                        320749  320749
# url                                         320749  320749
# creator                                     320770    3535
# created_t                                   320769  189567
# created_datetime                            320763  189568
# last_modified_t                             320772  180495
# last_modified_datetime                      320772  180495
# product_name                                303010  221347
# generic_name                                 52795   38584
# quantity                                    104819   13826
# packaging                                    78960   14547
# packaging_tags                               78961   12064
# brands                                      292360   58784
# brands_tags                                 292352   50253
# categories                                   84410   36982
# categories_tags                              84389   21142
# categories_fr                                84411   21152
# origins                                      22190    4840
# origins_tags                                 22153    4372
# manufacturing_places                         36501    7308
# manufacturing_places_tags                    36495    6736
# labels                                       46559   18114
# labels_tags                                  46644   13653
# labels_fr                                    46666   13655
# emb_codes                                    29306    8462
# emb_codes_tags                               29303    8158
# first_packaging_code_geo                     18803    1602
# cities                                          23       3
# cities_tags                                  20320    2572
# purchase_places                              58193    5120
# stores                                       51722    3259
# countries                                   320492    1434
# countries_tags                              320492     725
# countries_fr                                320492     722
# ingredients_text                            248962  205520
# allergens                                    28344   12939
# allergens_fr                                    19      19
# traces                                       24353    8378
# traces_tags                                  24329    3578
# traces_fr                                    24352    3584
# serving_size                                211331   25423
# additives                                   248905  196069
# additives_tags                              154680   41537
# additives_fr                                154680   41537
# ingredients_from_palm_oil_tags                4835      14
# ingredients_that_may_be_from_palm_oil_tags   11696     160
# nutrition_grade_fr                          221210       5
# pnns_groups_1                                91513      14
# pnns_groups_2                                94491      42
# states                                      320726    1021
# states_tags                                 320726    1021
# states_fr                                   320726    1021
# main_category                                84366    3543
# main_category_fr                             84366    3543
# image_url                                    75836   75836
# image_small_url                              75836   75836
#
#                                                                                           top  \
# code                                                                            0000000003087
# url                                         http://world-fr.openfoodfacts.org/produit/0000...
# creator                                                                       usda-ndb-import
# created_t                                                                          1489077120
# created_datetime                                                         2017-03-09T10:37:09Z
# last_modified_t                                                                    1439141742
# last_modified_datetime                                                   2015-08-09T17:35:42Z
# product_name                                                                        Ice Cream
# generic_name                                Pâtes alimentaires au blé dur de qualité supér...
# quantity                                                                                500 g
# packaging                                                                              Carton
# packaging_tags                                                               sachet,plastique
# brands                                                                              Carrefour
# brands_tags                                                                         carrefour
# categories                                         Snacks sucrés,Biscuits et gâteaux,Biscuits
# categories_tags                             en:sugary-snacks,en:biscuits-and-cakes,en:bisc...
# categories_fr                                      Snacks sucrés,Biscuits et gâteaux,Biscuits
# origins                                                                                France
# origins_tags                                                                           france
# manufacturing_places                                                                   France
# manufacturing_places_tags                                                              france
# labels                                      Organic, EU Organic, fr:AB Agriculture Biologique
# labels_tags                                 en:organic,en:eu-organic,fr:ab-agriculture-bio...
# labels_fr                                          Bio,Bio européen,AB Agriculture Biologique
# emb_codes                                                                          EMB 56251E
# emb_codes_tags                                                                     emb-56251e
# first_packaging_code_geo                                                  47.633333,-2.666667
# cities                                                                                      c
# cities_tags                                                             theix-morbihan-france
# purchase_places                                                                        France
# stores                                                                              Carrefour
# countries                                                                                  US
# countries_tags                                                               en:united-states
# countries_fr                                                                       États-Unis
# ingredients_text                                            Carbonated water, natural flavor.
# allergens                                                                                 blé
# allergens_fr                                http://fr.openfoodfacts.org/images/products/30...
# traces                                                                         Fruits à coque
# traces_tags                                                                           en:nuts
# traces_fr                                                                      Fruits à coque
# serving_size                                                                 240 ml (8 fl oz)
# additives                                    [ extra-virgin-olive-oil -> en:extra-virgin-o...
# additives_tags                                                                        en:e322
# additives_fr                                                                E322 - Lécithines
# ingredients_from_palm_oil_tags                                                 huile-de-palme
# ingredients_that_may_be_from_palm_oil_tags                                e160a-beta-carotene
# nutrition_grade_fr                                                                          d
# pnns_groups_1                                                                         unknown
# pnns_groups_2                                                                         unknown
# states                                      en:to-be-completed, en:nutrition-facts-complet...
# states_tags                                 en:to-be-completed,en:nutrition-facts-complete...
# states_fr                                   A compléter,Informations nutritionnelles compl...
# main_category                                                                    en:beverages
# main_category_fr                                                                     Boissons
# image_url                                   http://fr.openfoodfacts.org/images/products/00...
# image_small_url                             http://fr.openfoodfacts.org/images/products/00...
#
#                                               freq
# code                                             1
# url                                              1
# creator                                     169868
# created_t                                       20
# created_datetime                                20
# last_modified_t                                 33
# last_modified_datetime                          33
# product_name                                   410
# generic_name                                   201
# quantity                                      4669
# packaging                                     2153
# packaging_tags                                3959
# brands                                        2978
# brands_tags                                   3149
# categories                                     301
# categories_tags                                802
# categories_fr                                  802
# origins                                       5171
# origins_tags                                  5303
# manufacturing_places                          9371
# manufacturing_places_tags                     9451
# labels                                        3223
# labels_tags                                   5311
# labels_fr                                     5311
# emb_codes                                      218
# emb_codes_tags                                 218
# first_packaging_code_geo                       279
# cities                                           9
# cities_tags                                    270
# purchase_places                              11762
# stores                                        6465
# countries                                   169928
# countries_tags                              172998
# countries_fr                                172998
# ingredients_text                               222
# allergens                                     1279
# allergens_fr                                     1
# traces                                        1240
# traces_tags                                   2051
# traces_fr                                     2051
# serving_size                                  5496
# additives                                      397
# additives_tags                                8264
# additives_fr                                  8264
# ingredients_from_palm_oil_tags                4586
# ingredients_that_may_be_from_palm_oil_tags    2843
# nutrition_grade_fr                           62763
# pnns_groups_1                                22624
# pnns_groups_2                                22624
# states                                      168905
# states_tags                                 168905
# states_fr                                   168905
# main_category                                 6054
# main_category_fr                              6054
# image_url                                        1
# image_small_url                                  1

# %%
# Description des variables numériques
tools.get_description_variables(data, type_var='num')
# Out:
#                                             count         mean           std  \
# no_nutriments                                 0.0          NaN           NaN
# additives_n                              248939.0     1.936024  2.502019e+00
# ingredients_from_palm_oil_n              248939.0     0.019659  1.405241e-01
# ingredients_from_palm_oil                     0.0          NaN           NaN
# ingredients_that_may_be_from_palm_oil_n  248939.0     0.055246  2.692074e-01
# ingredients_that_may_be_from_palm_oil         0.0          NaN           NaN
# nutrition_grade_uk                            0.0          NaN           NaN
# energy_100g                              261113.0  1141.914605  6.447154e+03
# energy-from-fat_100g                        857.0   585.501214  7.128099e+02
# fat_100g                                 243891.0    12.730379  1.757875e+01
# saturated-fat_100g                       229554.0     5.129932  8.014238e+00
# butyric-acid_100g                             0.0          NaN           NaN
# caproic-acid_100g                             0.0          NaN           NaN
# caprylic-acid_100g                            1.0     7.400000           NaN
# capric-acid_100g                              2.0     6.040000  2.262742e-01
# lauric-acid_100g                              4.0    36.136182  2.410143e+01
# myristic-acid_100g                            1.0    18.900000           NaN
# palmitic-acid_100g                            1.0     8.100000           NaN
# stearic-acid_100g                             1.0     3.000000           NaN
# arachidic-acid_100g                          24.0    10.752667  4.019993e+00
# behenic-acid_100g                            23.0    10.673913  3.379647e+00
# lignoceric-acid_100g                          0.0          NaN           NaN
# cerotic-acid_100g                             0.0          NaN           NaN
# montanic-acid_100g                            1.0    61.000000           NaN
# melissic-acid_100g                            0.0          NaN           NaN
# monounsaturated-fat_100g                  22823.0    10.425055  1.707617e+01
# polyunsaturated-fat_100g                  22859.0     6.312493  1.083259e+01
# omega-3-fat_100g                            841.0     3.182103  5.607988e+00
# alpha-linolenic-acid_100g                   186.0     2.250285  7.971418e+00
# eicosapentaenoic-acid_100g                   38.0     3.186553  1.392775e+01
# docosahexaenoic-acid_100g                    78.0     1.635462  1.978192e+00
# omega-6-fat_100g                            188.0    16.229144  1.751263e+01
# linoleic-acid_100g                          149.0     3.823819  6.494183e+00
# trans-fat_100g                           3.690000e+02
# cholesterol_100g                         9.523800e+01
# carbohydrates_100g                       2.916670e+03
# sugars_100g                              3.520000e+03
# sucrose_100g                             9.280000e+01
# glucose_100g                             2.320000e+01
# fructose_100g                            1.010000e+02
# lactose_100g                             7.450000e+01
# maltose_100g                             3.920000e+01
# maltodextrins_100g                       2.750000e+01
# starch_100g                              8.780000e+01
# polyols_100g                             1.000000e+02
# fiber_100g                               5.380000e+03
# proteins_100g                            4.300000e+02
# casein_100g                              1.070000e+01
# serum-proteins_100g                      5.800000e+00
# nucleotides_100g                         2.500000e-02
# salt_100g                                6.431280e+04
# sodium_100g                              2.532000e+04
# alcohol_100g                             9.790000e+01
# vitamin-a_100g                           2.670000e+01
# beta-carotene_100g                       1.500000e+01
# vitamin-d_100g                           3.000000e-02
# vitamin-e_100g                           1.510000e+01
# vitamin-k_100g                           3.125000e+01
# vitamin-c_100g                           7.169811e+02
# vitamin-b1_100g                          1.610000e+02
# vitamin-b2_100g                          4.250000e+01
# vitamin-pp_100g                          2.142857e+01
# vitamin-b6_100g                          9.260000e+01
# vitamin-b9_100g                          2.307692e+01
# folates_100g                             1.785714e+02
# vitamin-b12_100g                         4.000000e-01
# biotin_100g                              6.000000e+00
# pantothenic-acid_100g                    6.000000e+01
# silica_100g                              2.500000e-01
# bicarbonate_100g                         1.250000e+00
# potassium_100g                           1.870370e+03
# chloride_100g                            5.890000e-01
# calcium_100g                             6.947370e+02
# phosphorus_100g                          5.594590e+02
# iron_100g                                5.000000e+01
# magnesium_100g                           6.571430e+02
# zinc_100g                                4.000000e+00
# copper_100g                              3.760000e+01
# manganese_100g                           7.000000e-01
# fluoride_100g                            5.600000e-01
# selenium_100g                            3.571429e+00
# chromium_100g                            3.000000e-02
# molybdenum_100g                          3.760000e-03
# iodine_100g                              1.470000e-02
# caffeine_100g                            4.228000e+01
# taurine_100g                             4.230000e-01
# ph_100g                                  8.400000e+00
# fruits-vegetables-nuts_100g              1.000000e+02
# collagen-meat-protein-ratio_100g         2.500000e+01
# cocoa_100g                               1.000000e+02
# chlorophyl_100g                                   NaN
# carbon-footprint_100g                    2.842000e+03
# nutrition-score-fr_100g                  4.000000e+01
# nutrition-score-uk_100g                  4.000000e+01
# glycemic-index_100g                               NaN
# water-hardness_100g                               NaN

# %% [markdown]
# # VISUALISATION DES NA

# %%
tools.get_missing_value(data,True,True)
# Out:
# Nombre total de données manquantes dans le dataframe : 39608589 données manquantes sur 51965064 (76.22%)
# -------------------------------------------------------------
# Nombre et pourcentage de valeurs manquantes par variable
# <style type="text/css">
# #T_22f29_row0_col0, #T_22f29_row0_col1, #T_22f29_row1_col0, #T_22f29_row1_col1, #T_22f29_row2_col0, #T_22f29_row2_col1, #T_22f29_row3_col0, #T_22f29_row3_col1, #T_22f29_row4_col0, #T_22f29_row4_col1, #T_22f29_row5_col0, #T_22f29_row5_col1, #T_22f29_row6_col0, #T_22f29_row6_col1, #T_22f29_row7_col0, #T_22f29_row7_col1, #T_22f29_row8_col0, #T_22f29_row8_col1, #T_22f29_row9_col0, #T_22f29_row9_col1, #T_22
# #T_22f29_row68_col0, #T_22f29_row68_col1, #T_22f29_row69_col0, #T_22f29_row69_col1, #T_22f29_row70_col0, #T_22f29_row70_col1, #T_22f29_row71_col0, #T_22f29_row71_col1 {
#   background-color: #820026;
#   color: #f1f1f1;
# }
# #T_22f29_row72_col0, #T_22f29_row72_col1, #T_22f29_row73_col0, #T_22f29_row73_col1 {
#   background-color: #840026;
#   color: #f1f1f1;
# }
# #T_22f29_row74_col0, #T_22f29_row74_col1, #T_22f29_row75_col0, #T_22f29_row75_col1, #T_22f29_row76_col0, #T_22f29_row76_col1 {
#   background-color: #860026;
#   color: #f1f1f1;
# }
# #T_22f29_row77_col0, #T_22f29_row77_col1, #T_22f29_row78_col0, #T_22f29_row78_col1, #T_22f29_row79_col0, #T_22f29_row79_col1, #T_22f29_row80_col0, #T_22f29_row80_col1 {
#   background-color: #880026;
#   color: #f1f1f1;
# }
# #T_22f29_row81_col0, #T_22f29_row81_col1, #T_22f29_row82_col0, #T_22f29_row82_col1 {
#   background-color: #8a0026;
#   color: #f1f1f1;
# }
# #T_22f29_row83_col0, #T_22f29_row83_col1, #T_22f29_row84_col0, #T_22f29_row84_col1 {
#   background-color: #8f0026;
#   color: #f1f1f1;
# }
# #T_22f29_row85_col0, #T_22f29_row85_col1, #T_22f29_row86_col0, #T_22f29_row86_col1 {
#   background-color: #910026;
#   color: #f1f1f1;
# }
# #T_22f29_row87_col0, #T_22f29_row87_col1 {
#   background-color: #9d0026;
#   color: #f1f1f1;
# }
# #T_22f29_row88_col0, #T_22f29_row88_col1 {
#   background-color: #9f0026;
#   color: #f1f1f1;
# }
# #T_22f29_row89_col0, #T_22f29_row89_col1, #T_22f29_row90_col0, #T_22f29_row90_col1 {
#   background-color: #a10026;
#   color: #f1f1f1;
# }
# #T_22f29_row91_col0, #T_22f29_row91_col1, #T_22f29_row92_col0, #T_22f29_row92_col1 {
#   background-color: #a20026;
#   color: #f1f1f1;
# }
# #T_22f29_row93_col0, #T_22f29_row93_col1, #T_22f29_row94_col0, #T_22f29_row94_col1, #T_22f29_row95_col0, #T_22f29_row95_col1, #T_22f29_row96_col0, #T_22f29_row96_col1 {
#   background-color: #a40026;
#   color: #f1f1f1;
# }
# #T_22f29_row97_col0, #T_22f29_row97_col1 {
#   background-color: #aa0026;
#   color: #f1f1f1;
# }
# #T_22f29_row98_col0, #T_22f29_row98_col1, #T_22f29_row99_col0, #T_22f29_row99_col1 {
#   background-color: #ac0026;
#   color: #f1f1f1;
# }
# #T_22f29_row100_col0, #T_22f29_row100_col1, #T_22f29_row101_col0, #T_22f29_row101_col1 {
#   background-color: #b70026;
#   color: #f1f1f1;
# }
# #T_22f29_row102_col0, #T_22f29_row102_col1, #T_22f29_row103_col0, #T_22f29_row103_col1, #T_22f29_row104_col0, #T_22f29_row104_col1 {
#   background-color: #c30424;
#   color: #f1f1f1;
# }
# #T_22f29_row105_col0, #T_22f29_row105_col1 {
#   background-color: #c80723;
#   color: #f1f1f1;
# }
# #T_22f29_row106_col0, #T_22f29_row106_col1 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_22f29_row107_col0, #T_22f29_row107_col1 {
#   background-color: #ce0c22;
#   color: #f1f1f1;
# }
# #T_22f29_row108_col0, #T_22f29_row108_col1, #T_22f29_row109_col0, #T_22f29_row109_col1 {
#   background-color: #df171d;
#   color: #f1f1f1;
# }
# #T_22f29_row110_col0, #T_22f29_row110_col1, #T_22f29_row111_col0, #T_22f29_row111_col1 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_22f29_row112_col0, #T_22f29_row112_col1, #T_22f29_row113_col0, #T_22f29_row113_col1, #T_22f29_row114_col0, #T_22f29_row114_col1, #T_22f29_row115_col0, #T_22f29_row115_col1, #T_22f29_row116_col0, #T_22f29_row116_col1 {
#   background-color: #e61f1d;
#   color: #f1f1f1;
# }
# #T_22f29_row117_col0, #T_22f29_row117_col1 {
#   background-color: #ea2920;
#   color: #f1f1f1;
# }
# #T_22f29_row118_col0, #T_22f29_row118_col1 {
#   background-color: #ec2c21;
#   color: #f1f1f1;
# }
# #T_22f29_row119_col0, #T_22f29_row119_col1 {
#   background-color: #f23924;
#   color: #f1f1f1;
# }
# #T_22f29_row120_col0, #T_22f29_row120_col1 {
#   background-color: #fc6832;
#   color: #f1f1f1;
# }
# #T_22f29_row121_col0, #T_22f29_row121_col1, #T_22f29_row122_col0, #T_22f29_row122_col1, #T_22f29_row123_col0, #T_22f29_row123_col1 {
#   background-color: #fd6e33;
#   color: #f1f1f1;
# }
# #T_22f29_row124_col0, #T_22f29_row124_col1, #T_22f29_row125_col0, #T_22f29_row125_col1 {
#   background-color: #fd7234;
#   color: #f1f1f1;
# }
# #T_22f29_row126_col0, #T_22f29_row126_col1, #T_22f29_row127_col0, #T_22f29_row127_col1 {
#   background-color: #fd8439;
#   color: #f1f1f1;
# }
# #T_22f29_row128_col0, #T_22f29_row128_col1 {
#   background-color: #feb34d;
#   color: #000000;
# }
# #T_22f29_row129_col0, #T_22f29_row129_col1 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_22f29_row130_col0, #T_22f29_row130_col1, #T_22f29_row131_col0, #T_22f29_row131_col1, #T_22f29_row132_col0, #T_22f29_row132_col1 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_22f29_row133_col0, #T_22f29_row133_col1 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_22f29_row134_col0, #T_22f29_row134_col1, #T_22f29_row135_col0, #T_22f29_row135_col1 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_22f29_row136_col0, #T_22f29_row136_col1 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_22f29_row137_col0, #T_22f29_row137_col1, #T_22f29_row138_col0, #T_22f29_row138_col1, #T_22f29_row139_col0, #T_22f29_row139_col1, #T_22f29_row140_col0, #T_22f29_row140_col1, #T_22f29_row141_col0, #T_22f29_row141_col1 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_22f29_row142_col0, #T_22f29_row142_col1, #T_22f29_row143_col0, #T_22f29_row143_col1 {
#   backgro
# ------------------------------------------------------------------
# Visualisation des données manquantes

# %% [markdown]
# # VALEURS MANQUANTES PAR VARIABLE

# %%
# Remplissage des variables
fix, ax = plt.fig
